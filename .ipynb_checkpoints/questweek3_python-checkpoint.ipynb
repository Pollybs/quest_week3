# %%
import pandas as pd
from sqlalchemy import create_engine 
import pymysql.cursors
import os
import getpass
import urllib.parse
import matplotlib.pyplot as plt
import wbgapi as wb

# %%
pw_raw = os.getenv('MySQLpwd')
pw = urllib.parse.quote_plus(pw_raw)

# %%
# pw = getpass.getpass("myslqp")

# %%
#engine = sqlalchemy.create_engine(f"mysql://{username}:{password}@{host}:{port}")

connection_string = 'mysql+pymysql://root:' + pw + '@localhost:3306/'
engine = create_engine(connection_string)

# %%
with engine.connect() as conn:
    conn.execute(f"CREATE DATABASE IF NOT EXISTS a_new_db_412")

# %%
df = pd.DataFrame({'Column1':[12,23,45]})

# %%
df
# Out:
#    Column1
# 0       12
# 1       23
# 2       45

# %%
df.to_sql('our_new_table',engine, 'ironhack2', if_exists='replace', index=False)
# Out:
# ---------------------------------------------------------------------------
# OperationalError                          Traceback (most recent call last)
# File ~/anaconda3/lib/python3.11/site-packages/sqlalchemy/engine/base.py:1819, in Connection._execute_context(self, dialect, constructor, statement, parameters, execution_options, *args, **kw)
#    1818     if not evt_handled:
# -> 1819         self.dialect.do_execute(
#    1820             cursor, statement, parameters, context
#    1821         )
#    1823 if self._has_events or self.engine._has_events:
#
# File ~/anaconda3/lib/python3.11/site-packages/sqlalchemy/engine/default.py:732, in DefaultDialect.do_execute(self, cursor, statement, parameters, context)
#     731 def do_execute(self, cursor, statement, parameters, context=None):
# --> 732     cursor.execute(statement, parameters)
#
# File ~/anaconda3/lib/python3.11/site-packages/pymysql/cursors.py:153, in Cursor.execute(self, query, args)
#     151 query = self.mogrify(query, args)
# --> 153 result = self._query(query)
#     154 self._executed = query
#
# File ~/anaconda3/lib/python3.11/site-packages/pymysql/cursors.py:322, in Cursor._query(self, q)
#     321 self._clear_result()
# --> 322 conn.query(q)
#     323 self._do_get_result()
#
# File ~/anaconda3/lib/python3.11/site-packages/pymysql/connections.py:558, in Connection.query(self, sql, unbuffered)
#     557 self._execute_command(COMMAND.COM_QUERY, sql)
# --> 558 self._affected_rows = self._read_query_result(unbuffered=unbuffered)
#     559 return self._affected_rows
#
# File ~/anaconda3/lib/python3.11/site-packages/pymysql/connections.py:822, in Connection._read_query_result(self, unbuffered)
#     821     result = MySQLResult(self)
# --> 822     result.read()
#     823 self._result = result
#
# File ~/anaconda3/lib/python3.11/site-packages/pymysql/connections.py:1200, in MySQLResult.read(self)
#    1199 try:
# -> 1200     first_packet = self.connection._read_packet()
#    1202     if first_packet.is_ok_packet():
#
# File ~/anaconda3/lib/python3.11/site-packages/pymysql/connections.py:772, in Connection._read_packet(self, packet_type)
#     771         self._result.unbuffered_active = False
# --> 772     packet.raise_for_error()
#     773 return packet
#
# File ~/anaconda3/lib/python3.11/site-packages/pymysql/protocol.py:221, in MysqlPacket.raise_for_error(self)
#     220     print("errno =", errno)
# --> 221 err.raise_mysql_exception(self._data)
#
# File ~/anaconda3/lib/python3.11/site-packages/pymysql/err.py:143, in raise_mysql_exception(data)
#     142     errorclass = InternalError if errno < 1000 else OperationalError
# --> 143 raise errorclass(errno, errval)
#
# OperationalError: (1049, "Unknown database 'ironhack2'")
#
# The above exception was the direct cause of the following exception:
#
# OperationalError                          Traceback (most recent call last)
# Cell In[11], line 1
# ----> 1 df.to_sql('our_new_table',engine, 'ironhack2', if_exists='replace', index=False)
#
# File ~/anaconda3/lib/python3.11/site-packages/pandas/core/generic.py:2878, in NDFrame.to_sql(self, name, con, schema, if_exists, index, index_label, chunksize, dtype, method)
#    2713 """
#    2714 Write records stored in a DataFrame to a SQL database.
#    2715
#    (...)
#    2874 [(1,), (None,), (2,)]
#    2875 """  # noqa:E501
#    2876 from pandas.io import sql
# -> 2878 return sql.to_sql(
#    2879     self,
#    2880     name,
#    2881     con,
#    2882     schema=schema,
#    2883     if_exists=if_exists,
#    2884     index=index,
#    2885     index_label=index_label,
#    2886     chunksize=chunksize,
#    2887     dtype=dtype,
#    2888     method=method,
#    2889 )
#
# File ~/anaconda3/lib/python3.11/site-packages/pandas/io/sql.py:769, in to_sql(frame, name, con, schema, if_exists, index, index_label, chunksize, dtype, method, engine, **engine_kwargs)
#     764     raise NotImplementedError(
#     765         "'frame' argument should be either a Series or a DataFrame"
#     766     )
#     768 with pandasSQL_builder(con, schema=schema, need_transaction=True) as pandas_sql:
# --> 769     return pandas_sql.to_sql(
#     770         frame,
#     771         name,
#     772         if_exists=if_exists,
#     773         index=index,
#     774         index_label=index_label,
#     775         schema=schema,
#     776         chunksize=chunksize,
#     777         dtype=dtype,
#     778         method=method,
#     779         engine=engine,
#     780         **engine_kwargs,
#     781     )
#
# File ~/anaconda3/lib/python3.11/site-packages/pandas/io/sql.py:1910, in SQLDatabase.to_sql(self, frame, name, if_exists, index, index_label, schema, chunksize, dtype, method, engine, **engine_kwargs)
#    1860 """
#    1861 Write records stored in a DataFrame to a SQL database.
#    1862
#    (...)
#    1906     Any additional kwargs are passed to the engine.
#    1907 """
#    1908 sql_engine = get_engine(engine)
# -> 1910 table = self.prep_table(
#    1911     frame=frame,
#    1912     name=name,
#    1913     if_exists=if_exists,
#    1914     index=index,
#    1915     index_label=index_label,
#    1916     schema=schema,
#    1917     dtype=dtype,
#    1918 )
#    1920 total_inserted = sql_engine.insert_records(
#    1921     table=table,
#    1922     con=self.con,
#    (...)
#    1929     **engine_kwargs,
#    1930 )
#    1932 self.check_case_sensitive(name=name, schema=schema)
#
# File ~/anaconda3/lib/python3.11/site-packages/pandas/io/sql.py:1814, in SQLDatabase.prep_table(self, frame, name, if_exists, index, index_label, schema, dtype)
#    1802             raise ValueError(f"The type of {col} is not a SQLAlchemy type")
#    1804 table = SQLTable(
#    1805     name,
#    1806     self,
#    (...)
#    1812     dtype=dtype,
#    1813 )
# -> 1814 table.create()
#    1815 return table
#
# File ~/anaconda3/lib/python3.11/site-packages/pandas/io/sql.py:914, in SQLTable.create(self)
#     912         raise ValueError(f"'{self.if_exists}' is not valid for if_exists")
#     913 else:
# --> 914     self._execute_create()
#
# File ~/anaconda3/lib/python3.11/site-packages/pandas/io/sql.py:900, in SQLTable._execute_create(self)
#     898 self.table = self.table.to_metadata(self.pd_sql.meta)
#     899 with self.pd_sql.run_transaction():
# --> 900     self.table.create(bind=self.pd_sql.con)
#
# File ~/anaconda3/lib/python3.11/site-packages/sqlalchemy/sql/schema.py:959, in Table.create(self, bind, checkfirst)
#     957 if bind is None:
#     958     bind = _bind_or_error(self)
# --> 959 bind._run_ddl_visitor(ddl.SchemaGenerator, self, checkfirst=checkfirst)
#
# File ~/anaconda3/lib/python3.11/site-packages/sqlalchemy/engine/base.py:2130, in Connection._run_ddl_visitor(self, visitorcallable, element, **kwargs)
#    2123 def _run_ddl_visitor(self, visitorcallable, element, **kwargs):
#    2124     """run a DDL visitor.
#    2125
#    2126     This method is only here so that the MockConnection can change the
#    2127     options given to the visitor so that "checkfirst" is skipped.
#    2128
#    2129     """
# -> 2130     visitorcallable(self.dialect, self, **kwargs).traverse_single(element)
#
# File ~/anaconda3/lib/python3.11/site-packages/sqlalchemy/sql/visitors.py:524, in ExternalTraversal.traverse_single(self, obj, **kw)
#     522 meth = getattr(v, "visit_%s" % obj.__visit_name__, None)
#     523 if meth:
# --> 524     return meth(obj, **kw)
#
# File ~/anaconda3/lib/python3.11/site-packages/sqlalchemy/sql/ddl.py:895, in SchemaGenerator.visit_table(self, table, create_ok, include_foreign_key_constraints, _is_metadata_operation)
#     891 if not self.dialect.supports_alter:
#     892     # e.g., don't omit any foreign key constraints
#     893     include_foreign_key_constraints = None
# --> 895 self.connection.execute(
#     896     # fmt: off
#     897     CreateTable(
#     898         table,
#     899         include_foreign_key_constraints=  # noqa
#     900             include_foreign_key_constraints,  # noqa
#     901     )
#     902     # fmt: on
#     903 )
#     905 if hasattr(table, "indexes"):
#     906     for index in table.indexes:
#
# File ~/anaconda3/lib/python3.11/site-packages/sqlalchemy/engine/base.py:1306, in Connection.execute(self, statement, *multiparams, **params)
#    1302     util.raise_(
#    1303         exc.ObjectNotExecutableError(statement), replace_context=err
#    1304     )
#    1305 else:
# -> 1306     return meth(self, multiparams, params, _EMPTY_EXECUTION_OPTS)
#
# File ~/anaconda3/lib/python3.11/site-packages/sqlalchemy/sql/ddl.py:80, in DDLElement._execute_on_connection(self, connection, multiparams, params, execution_options)
#      77 def _execute_on_connection(
#      78     self, connection, multiparams, params, execution_options
#      79 ):
# ---> 80     return connection._execute_ddl(
#      81         self, multiparams, params, execution_options
#      82     )
#
# File ~/anaconda3/lib/python3.11/site-packages/sqlalchemy/engine/base.py:1398, in Connection._execute_ddl(self, ddl, multiparams, params, execution_options)
#    1393 dialect = self.dialect
#    1395 compiled = ddl.compile(
#    1396     dialect=dialect, schema_translate_map=schema_translate_map
#    1397 )
# -> 1398 ret = self._execute_context(
#    1399     dialect,
#    1400     dialect.execution_ctx_cls._init_ddl,
#    1401     compiled,
#    1402     None,
#    1403     execution_options,
#    1404     compiled,
#    1405 )
#    1406 if self._has_events or self.engine._has_events:
#    1407     self.dispatch.after_execute(
#    1408         self,
#    1409         ddl,
#    (...)
#    1413         ret,
#    1414     )
#
# File ~/anaconda3/lib/python3.11/site-packages/sqlalchemy/engine/base.py:1862, in Connection._execute_context(self, dialect, constructor, statement, parameters, execution_options, *args, **kw)
#    1859             branched.close()
#    1861 except BaseException as e:
# -> 1862     self._handle_dbapi_exception(
#    1863         e, statement, parameters, cursor, context
#    1864     )
#    1866 return result
#
# File ~/anaconda3/lib/python3.11/site-packages/sqlalchemy/engine/base.py:2043, in Connection._handle_dbapi_exception(self, e, statement, parameters, cursor, context)
#    2041     util.raise_(newraise, with_traceback=exc_info[2], from_=e)
#    2042 elif should_wrap:
# -> 2043     util.raise_(
#    2044         sqlalchemy_exception, with_traceback=exc_info[2], from_=e
#    2045     )
#    2046 else:
#    2047     util.raise_(exc_info[1], with_traceback=exc_info[2])
#
# File ~/anaconda3/lib/python3.11/site-packages/sqlalchemy/util/compat.py:208, in raise_(***failed resolving arguments***)
#     205     exception.__cause__ = replace_context
#     207 try:
# --> 208     raise exception
#     209 finally:
#     210     # credit to
#     211     # https://cosmicpercolator.com/2016/01/13/exception-leaks-in-python-2-and-3/
#     212     # as the __traceback__ object creates a cycle
#     213     del exception, replace_context, from_, with_traceback
#
# File ~/anaconda3/lib/python3.11/site-packages/sqlalchemy/engine/base.py:1819, in Connection._execute_context(self, dialect, constructor, statement, parameters, execution_options, *args, **kw)
#    1817                 break
#    1818     if not evt_handled:
# -> 1819         self.dialect.do_execute(
#    1820             cursor, statement, parameters, context
#    1821         )
#    1823 if self._has_events or self.engine._has_events:
#    1824     self.dispatch.after_cursor_execute(
#    1825         self,
#    1826         cursor,
#    (...)
#    1830         context.executemany,
#    1831     )
#
# File ~/anaconda3/lib/python3.11/site-packages/sqlalchemy/engine/default.py:732, in DefaultDialect.do_execute(self, cursor, statement, parameters, context)
#     731 def do_execute(self, cursor, statement, parameters, context=None):
# --> 732     cursor.execute(statement, parameters)
#
# File ~/anaconda3/lib/python3.11/site-packages/pymysql/cursors.py:153, in Cursor.execute(self, query, args)
#     149     pass
#     151 query = self.mogrify(query, args)
# --> 153 result = self._query(query)
#     154 self._executed = query
#     155 return result
#
# File ~/anaconda3/lib/python3.11/site-packages/pymysql/cursors.py:322, in Cursor._query(self, q)
#     320 conn = self._get_db()
#     321 self._clear_result()
# --> 322 conn.query(q)
#     323 self._do_get_result()
#     324 return self.rowcount
#
# File ~/anaconda3/lib/python3.11/site-packages/pymysql/connections.py:558, in Connection.query(self, sql, unbuffered)
#     556     sql = sql.encode(self.encoding, "surrogateescape")
#     557 self._execute_command(COMMAND.COM_QUERY, sql)
# --> 558 self._affected_rows = self._read_query_result(unbuffered=unbuffered)
#     559 return self._affected_rows
#
# File ~/anaconda3/lib/python3.11/site-packages/pymysql/connections.py:822, in Connection._read_query_result(self, unbuffered)
#     820 else:
#     821     result = MySQLResult(self)
# --> 822     result.read()
#     823 self._result = result
#     824 if result.server_status is not None:
#
# File ~/anaconda3/lib/python3.11/site-packages/pymysql/connections.py:1200, in MySQLResult.read(self)
#    1198 def read(self):
#    1199     try:
# -> 1200         first_packet = self.connection._read_packet()
#    1202         if first_packet.is_ok_packet():
#    1203             self._read_ok_packet(first_packet)
#
# File ~/anaconda3/lib/python3.11/site-packages/pymysql/connections.py:772, in Connection._read_packet(self, packet_type)
#     770     if self._result is not None and self._result.unbuffered_active is True:
#     771         self._result.unbuffered_active = False
# --> 772     packet.raise_for_error()
#     773 return packet
#
# File ~/anaconda3/lib/python3.11/site-packages/pymysql/protocol.py:221, in MysqlPacket.raise_for_error(self)
#     219 if DEBUG:
#     220     print("errno =", errno)
# --> 221 err.raise_mysql_exception(self._data)
#
# File ~/anaconda3/lib/python3.11/site-packages/pymysql/err.py:143, in raise_mysql_exception(data)
#     141 if errorclass is None:
#     142     errorclass = InternalError if errno < 1000 else OperationalError
# --> 143 raise errorclass(errno, errval)
#
# OperationalError: (pymysql.err.OperationalError) (1049, "Unknown database 'ironhack2'")
# [SQL:
# CREATE TABLE ironhack2.our_new_table (
# 	`Column1` BIGINT
# )
#
# ]
# (Background on this error at: https://sqlalche.me/e/14/e3q8)

# %%
# 
sql = """
select * from classicmodels.payments, count(*) as volume
from alchemy_test.admission_predict
group by 1
"""

# %%
sql = """
select * from classicmodels.payments
"""

# %%
new_df = pd.read_sql_query(sql, engine)

# %%
new_df
# Out:
#      customerNumber checkNumber paymentDate    amount
# 0               103    HQ336336  2004-10-19   6066.78
# 1               103    JM555205  2003-06-05  14571.44
# 2               103    OM314933  2004-12-18   1676.14
# 3               112    BO864823  2004-12-17  14191.12
# 4               112     HQ55022  2003-06-06  32641.98
# ..              ...         ...         ...       ...
# 268             495    BH167026  2003-12-26  59265.14
# 269             495    FN155234  2004-05-14   6276.60
# 270             496    EU531600  2005-05-25  30253.75
# 271             496    MB342426  2003-07-16  32077.44
# 272             496     MN89921  2004-12-31  52166.00
#
# [273 rows x 4 columns]

# %%
newdf2=pd.read_sql_table("payments", engine,"classicmodels")
newdf2
# Out:
#      customerNumber checkNumber paymentDate    amount
# 0               103    HQ336336  2004-10-19   6066.78
# 1               103    JM555205  2003-06-05  14571.44
# 2               103    OM314933  2004-12-18   1676.14
# 3               112    BO864823  2004-12-17  14191.12
# 4               112     HQ55022  2003-06-06  32641.98
# ..              ...         ...         ...       ...
# 268             495    BH167026  2003-12-26  59265.14
# 269             495    FN155234  2004-05-14   6276.60
# 270             496    EU531600  2005-05-25  30253.75
# 271             496    MB342426  2003-07-16  32077.44
# 272             496     MN89921  2004-12-31  52166.00
#
# [273 rows x 4 columns]

# %%
wb.series.info(q='forest')
# Out:
# id                 value
# -----------------  ------------------------------------------------------------------------------
# AG.LND.FRST.K2     Forest area (sq. km)
# AG.LND.FRST.ZS     Forest area (% of land area)
# NV.AGR.EMPL.KD     Agriculture, forestry, and fishing, value added per worker (constant 2015 US$)
# NV.AGR.TOTL.CD     Agriculture, forestry, and fishing, value added (current US$)
# NV.AGR.TOTL.CN     Agriculture, forestry, and fishing, value added (current LCU)
# NV.AGR.TOTL.KD     Agriculture, forestry, and fishing, value added (constant 2015 US$)
# NV.AGR.TOTL.KD.ZG  Agriculture, forestry, and fishing, value added (annual % growth)
# NV.AGR.TOTL.KN     Agriculture, forestry, and fishing, value added (constant LCU)
# NV.AGR.TOTL.ZS     Agriculture, forestry, and fishing, value added (% of GDP)
# NY.ADJ.DFOR.CD     Adjusted savings: net forest depletion (current US$)
# NY.ADJ.DFOR.GN.ZS  Adjusted savings: net forest depletion (% of GNI)
# NY.GDP.FRST.RT.ZS  Forest rents (% of GDP)
#                    12 elements

# %%
co2_emissions = wb.data.DataFrame('EN.ATM.CO2E.KD.GD', ['AFG', 'ARG','BRA','CHN','DEU','FRA','GBR','JPN','LBN','POL','UKR','URY','USA'], time=range(2010,2021))
co2_emissions.head()
co2_emissions.reset_index().to_sql('co2_emissions', engine, 'sustainable_var', if_exists='replace', index=False)
# Out:
# ---------------------------------------------------------------------------
# OperationalError                          Traceback (most recent call last)
# File ~/anaconda3/lib/python3.11/site-packages/sqlalchemy/engine/base.py:1819, in Connection._execute_context(self, dialect, constructor, statement, parameters, execution_options, *args, **kw)
#    1818     if not evt_handled:
# -> 1819         self.dialect.do_execute(
#    1820             cursor, statement, parameters, context
#    1821         )
#    1823 if self._has_events or self.engine._has_events:
#
# File ~/anaconda3/lib/python3.11/site-packages/sqlalchemy/engine/default.py:732, in DefaultDialect.do_execute(self, cursor, statement, parameters, context)
#     731 def do_execute(self, cursor, statement, parameters, context=None):
# --> 732     cursor.execute(statement, parameters)
#
# File ~/anaconda3/lib/python3.11/site-packages/pymysql/cursors.py:153, in Cursor.execute(self, query, args)
#     151 query = self.mogrify(query, args)
# --> 153 result = self._query(query)
#     154 self._executed = query
#
# File ~/anaconda3/lib/python3.11/site-packages/pymysql/cursors.py:322, in Cursor._query(self, q)
#     321 self._clear_result()
# --> 322 conn.query(q)
#     323 self._do_get_result()
#
# File ~/anaconda3/lib/python3.11/site-packages/pymysql/connections.py:558, in Connection.query(self, sql, unbuffered)
#     557 self._execute_command(COMMAND.COM_QUERY, sql)
# --> 558 self._affected_rows = self._read_query_result(unbuffered=unbuffered)
#     559 return self._affected_rows
#
# File ~/anaconda3/lib/python3.11/site-packages/pymysql/connections.py:822, in Connection._read_query_result(self, unbuffered)
#     821     result = MySQLResult(self)
# --> 822     result.read()
#     823 self._result = result
#
# File ~/anaconda3/lib/python3.11/site-packages/pymysql/connections.py:1200, in MySQLResult.read(self)
#    1199 try:
# -> 1200     first_packet = self.connection._read_packet()
#    1202     if first_packet.is_ok_packet():
#
# File ~/anaconda3/lib/python3.11/site-packages/pymysql/connections.py:772, in Connection._read_packet(self, packet_type)
#     771         self._result.unbuffered_active = False
# --> 772     packet.raise_for_error()
#     773 return packet
#
# File ~/anaconda3/lib/python3.11/site-packages/pymysql/protocol.py:221, in MysqlPacket.raise_for_error(self)
#     220     print("errno =", errno)
# --> 221 err.raise_mysql_exception(self._data)
#
# File ~/anaconda3/lib/python3.11/site-packages/pymysql/err.py:143, in raise_mysql_exception(data)
#     142     errorclass = InternalError if errno < 1000 else OperationalError
# --> 143 raise errorclass(errno, errval)
#
# OperationalError: (1049, "Unknown database 'sustainable_var'")
#
# The above exception was the direct cause of the following exception:
#
# OperationalError                          Traceback (most recent call last)
# Cell In[18], line 3
#       1 co2_emissions = wb.data.DataFrame('EN.ATM.CO2E.KD.GD', ['AFG', 'ARG','BRA','CHN','DEU','FRA','GBR','JPN','LBN','POL','UKR','URY','USA'], time=range(2010,2021))
#       2 co2_emissions.head()
# ----> 3 co2_emissions.reset_index().to_sql('co2_emissions', engine, 'sustainable_var', if_exists='replace', index=False)
#
# File ~/anaconda3/lib/python3.11/site-packages/pandas/core/generic.py:2878, in NDFrame.to_sql(self, name, con, schema, if_exists, index, index_label, chunksize, dtype, method)
#    2713 """
#    2714 Write records stored in a DataFrame to a SQL database.
#    2715
#    (...)
#    2874 [(1,), (None,), (2,)]
#    2875 """  # noqa:E501
#    2876 from pandas.io import sql
# -> 2878 return sql.to_sql(
#    2879     self,
#    2880     name,
#    2881     con,
#    2882     schema=schema,
#    2883     if_exists=if_exists,
#    2884     index=index,
#    2885     index_label=index_label,
#    2886     chunksize=chunksize,
#    2887     dtype=dtype,
#    2888     method=method,
#    2889 )
#
# File ~/anaconda3/lib/python3.11/site-packages/pandas/io/sql.py:769, in to_sql(frame, name, con, schema, if_exists, index, index_label, chunksize, dtype, method, engine, **engine_kwargs)
#     764     raise NotImplementedError(
#     765         "'frame' argument should be either a Series or a DataFrame"
#     766     )
#     768 with pandasSQL_builder(con, schema=schema, need_transaction=True) as pandas_sql:
# --> 769     return pandas_sql.to_sql(
#     770         frame,
#     771         name,
#     772         if_exists=if_exists,
#     773         index=index,
#     774         index_label=index_label,
#     775         schema=schema,
#     776         chunksize=chunksize,
#     777         dtype=dtype,
#     778         method=method,
#     779         engine=engine,
#     780         **engine_kwargs,
#     781     )
#
# File ~/anaconda3/lib/python3.11/site-packages/pandas/io/sql.py:1910, in SQLDatabase.to_sql(self, frame, name, if_exists, index, index_label, schema, chunksize, dtype, method, engine, **engine_kwargs)
#    1860 """
#    1861 Write records stored in a DataFrame to a SQL database.
#    1862
#    (...)
#    1906     Any additional kwargs are passed to the engine.
#    1907 """
#    1908 sql_engine = get_engine(engine)
# -> 1910 table = self.prep_table(
#    1911     frame=frame,
#    1912     name=name,
#    1913     if_exists=if_exists,
#    1914     index=index,
#    1915     index_label=index_label,
#    1916     schema=schema,
#    1917     dtype=dtype,
#    1918 )
#    1920 total_inserted = sql_engine.insert_records(
#    1921     table=table,
#    1922     con=self.con,
#    (...)
#    1929     **engine_kwargs,
#    1930 )
#    1932 self.check_case_sensitive(name=name, schema=schema)
#
# File ~/anaconda3/lib/python3.11/site-packages/pandas/io/sql.py:1814, in SQLDatabase.prep_table(self, frame, name, if_exists, index, index_label, schema, dtype)
#    1802             raise ValueError(f"The type of {col} is not a SQLAlchemy type")
#    1804 table = SQLTable(
#    1805     name,
#    1806     self,
#    (...)
#    1812     dtype=dtype,
#    1813 )
# -> 1814 table.create()
#    1815 return table
#
# File ~/anaconda3/lib/python3.11/site-packages/pandas/io/sql.py:914, in SQLTable.create(self)
#     912         raise ValueError(f"'{self.if_exists}' is not valid for if_exists")
#     913 else:
# --> 914     self._execute_create()
#
# File ~/anaconda3/lib/python3.11/site-packages/pandas/io/sql.py:900, in SQLTable._execute_create(self)
#     898 self.table = self.table.to_metadata(self.pd_sql.meta)
#     899 with self.pd_sql.run_transaction():
# --> 900     self.table.create(bind=self.pd_sql.con)
#
# File ~/anaconda3/lib/python3.11/site-packages/sqlalchemy/sql/schema.py:959, in Table.create(self, bind, checkfirst)
#     957 if bind is None:
#     958     bind = _bind_or_error(self)
# --> 959 bind._run_ddl_visitor(ddl.SchemaGenerator, self, checkfirst=checkfirst)
#
# File ~/anaconda3/lib/python3.11/site-packages/sqlalchemy/engine/base.py:2130, in Connection._run_ddl_visitor(self, visitorcallable, element, **kwargs)
#    2123 def _run_ddl_visitor(self, visitorcallable, element, **kwargs):
#    2124     """run a DDL visitor.
#    2125
#    2126     This method is only here so that the MockConnection can change the
#    2127     options given to the visitor so that "checkfirst" is skipped.
#    2128
#    2129     """
# -> 2130     visitorcallable(self.dialect, self, **kwargs).traverse_single(element)
#
# File ~/anaconda3/lib/python3.11/site-packages/sqlalchemy/sql/visitors.py:524, in ExternalTraversal.traverse_single(self, obj, **kw)
#     522 meth = getattr(v, "visit_%s" % obj.__visit_name__, None)
#     523 if meth:
# --> 524     return meth(obj, **kw)
#
# File ~/anaconda3/lib/python3.11/site-packages/sqlalchemy/sql/ddl.py:895, in SchemaGenerator.visit_table(self, table, create_ok, include_foreign_key_constraints, _is_metadata_operation)
#     891 if not self.dialect.supports_alter:
#     892     # e.g., don't omit any foreign key constraints
#     893     include_foreign_key_constraints = None
# --> 895 self.connection.execute(
#     896     # fmt: off
#     897     CreateTable(
#     898         table,
#     899         include_foreign_key_constraints=  # noqa
#     900             include_foreign_key_constraints,  # noqa
#     901     )
#     902     # fmt: on
#     903 )
#     905 if hasattr(table, "indexes"):
#     906     for index in table.indexes:
#
# File ~/anaconda3/lib/python3.11/site-packages/sqlalchemy/engine/base.py:1306, in Connection.execute(self, statement, *multiparams, **params)
#    1302     util.raise_(
#    1303         exc.ObjectNotExecutableError(statement), replace_context=err
#    1304     )
#    1305 else:
# -> 1306     return meth(self, multiparams, params, _EMPTY_EXECUTION_OPTS)
#
# File ~/anaconda3/lib/python3.11/site-packages/sqlalchemy/sql/ddl.py:80, in DDLElement._execute_on_connection(self, connection, multiparams, params, execution_options)
#      77 def _execute_on_connection(
#      78     self, connection, multiparams, params, execution_options
#      79 ):
# ---> 80     return connection._execute_ddl(
#      81         self, multiparams, params, execution_options
#      82     )
#
# File ~/anaconda3/lib/python3.11/site-packages/sqlalchemy/engine/base.py:1398, in Connection._execute_ddl(self, ddl, multiparams, params, execution_options)
#    1393 dialect = self.dialect
#    1395 compiled = ddl.compile(
#    1396     dialect=dialect, schema_translate_map=schema_translate_map
#    1397 )
# -> 1398 ret = self._execute_context(
#    1399     dialect,
#    1400     dialect.execution_ctx_cls._init_ddl,
#    1401     compiled,
#    1402     None,
#    1403     execution_options,
#    1404     compiled,
#    1405 )
#    1406 if self._has_events or self.engine._has_events:
#    1407     self.dispatch.after_execute(
#    1408         self,
#    1409         ddl,
#    (...)
#    1413         ret,
#    1414     )
#
# File ~/anaconda3/lib/python3.11/site-packages/sqlalchemy/engine/base.py:1862, in Connection._execute_context(self, dialect, constructor, statement, parameters, execution_options, *args, **kw)
#    1859             branched.close()
#    1861 except BaseException as e:
# -> 1862     self._handle_dbapi_exception(
#    1863         e, statement, parameters, cursor, context
#    1864     )
#    1866 return result
#
# File ~/anaconda3/lib/python3.11/site-packages/sqlalchemy/engine/base.py:2043, in Connection._handle_dbapi_exception(self, e, statement, parameters, cursor, context)
#    2041     util.raise_(newraise, with_traceback=exc_info[2], from_=e)
#    2042 elif should_wrap:
# -> 2043     util.raise_(
#    2044         sqlalchemy_exception, with_traceback=exc_info[2], from_=e
#    2045     )
#    2046 else:
#    2047     util.raise_(exc_info[1], with_traceback=exc_info[2])
#
# File ~/anaconda3/lib/python3.11/site-packages/sqlalchemy/util/compat.py:208, in raise_(***failed resolving arguments***)
#     205     exception.__cause__ = replace_context
#     207 try:
# --> 208     raise exception
#     209 finally:
#     210     # credit to
#     211     # https://cosmicpercolator.com/2016/01/13/exception-leaks-in-python-2-and-3/
#     212     # as the __traceback__ object creates a cycle
#     213     del exception, replace_context, from_, with_traceback
#
# File ~/anaconda3/lib/python3.11/site-packages/sqlalchemy/engine/base.py:1819, in Connection._execute_context(self, dialect, constructor, statement, parameters, execution_options, *args, **kw)
#    1817                 break
#    1818     if not evt_handled:
# -> 1819         self.dialect.do_execute(
#    1820             cursor, statement, parameters, context
#    1821         )
#    1823 if self._has_events or self.engine._has_events:
#    1824     self.dispatch.after_cursor_execute(
#    1825         self,
#    1826         cursor,
#    (...)
#    1830         context.executemany,
#    1831     )
#
# File ~/anaconda3/lib/python3.11/site-packages/sqlalchemy/engine/default.py:732, in DefaultDialect.do_execute(self, cursor, statement, parameters, context)
#     731 def do_execute(self, cursor, statement, parameters, context=None):
# --> 732     cursor.execute(statement, parameters)
#
# File ~/anaconda3/lib/python3.11/site-packages/pymysql/cursors.py:153, in Cursor.execute(self, query, args)
#     149     pass
#     151 query = self.mogrify(query, args)
# --> 153 result = self._query(query)
#     154 self._executed = query
#     155 return result
#
# File ~/anaconda3/lib/python3.11/site-packages/pymysql/cursors.py:322, in Cursor._query(self, q)
#     320 conn = self._get_db()
#     321 self._clear_result()
# --> 322 conn.query(q)
#     323 self._do_get_result()
#     324 return self.rowcount
#
# File ~/anaconda3/lib/python3.11/site-packages/pymysql/connections.py:558, in Connection.query(self, sql, unbuffered)
#     556     sql = sql.encode(self.encoding, "surrogateescape")
#     557 self._execute_command(COMMAND.COM_QUERY, sql)
# --> 558 self._affected_rows = self._read_query_result(unbuffered=unbuffered)
#     559 return self._affected_rows
#
# File ~/anaconda3/lib/python3.11/site-packages/pymysql/connections.py:822, in Connection._read_query_result(self, unbuffered)
#     820 else:
#     821     result = MySQLResult(self)
# --> 822     result.read()
#     823 self._result = result
#     824 if result.server_status is not None:
#
# File ~/anaconda3/lib/python3.11/site-packages/pymysql/connections.py:1200, in MySQLResult.read(self)
#    1198 def read(self):
#    1199     try:
# -> 1200         first_packet = self.connection._read_packet()
#    1202         if first_packet.is_ok_packet():
#    1203             self._read_ok_packet(first_packet)
#
# File ~/anaconda3/lib/python3.11/site-packages/pymysql/connections.py:772, in Connection._read_packet(self, packet_type)
#     770     if self._result is not None and self._result.unbuffered_active is True:
#     771         self._result.unbuffered_active = False
# --> 772     packet.raise_for_error()
#     773 return packet
#
# File ~/anaconda3/lib/python3.11/site-packages/pymysql/protocol.py:221, in MysqlPacket.raise_for_error(self)
#     219 if DEBUG:
#     220     print("errno =", errno)
# --> 221 err.raise_mysql_exception(self._data)
#
# File ~/anaconda3/lib/python3.11/site-packages/pymysql/err.py:143, in raise_mysql_exception(data)
#     141 if errorclass is None:
#     142     errorclass = InternalError if errno < 1000 else OperationalError
# --> 143 raise errorclass(errno, errval)
#
# OperationalError: (pymysql.err.OperationalError) (1049, "Unknown database 'sustainable_var'")
# [SQL:
# CREATE TABLE sustainable_var.co2_emissions (
# 	economy TEXT,
# 	`YR2010` FLOAT(53),
# 	`YR2011` FLOAT(53),
# 	`YR2012` FLOAT(53),
# 	`YR2013` FLOAT(53),
# 	`YR2014` FLOAT(53),
# 	`YR2015` FLOAT(53),
# 	`YR2016` FLOAT(53),
# 	`YR2017` FLOAT(53),
# 	`YR2018` FLOAT(53),
# 	`YR2019` FLOAT(53),
# 	`YR2020` FLOAT(53)
# )
#
# ]
# (Background on this error at: https://sqlalche.me/e/14/e3q8)

# %%
natural_resources_depletion = wb.data.DataFrame('NY.ADJ.DRES.GN.ZS', ['AFG', 'ARG','BRA','CHN','DEU','FRA','GBR','JPN','LBN','POL','UKR','URY','USA'], time=range(2010,2021))
natural_resources_depletion.head()
natural_resources_depletion.reset_index().to_sql('natural_resources_depletion', engine, 'sustainable_var', if_exists='replace', index=False)

# %%
water_depletion = wb.data.DataFrame('ER.H2O.FWST.ZS', ['AFG', 'ARG','BRA','CHN','DEU','FRA','GBR','JPN','LBN','POL','UKR','URY','USA'], time=range(2010,2021))
water_depletion.head()
water_depletion.reset_index().to_sql('water_depletion', engine, 'sustainable_var', if_exists='replace', index=False)

# %%
renewable_energy_consumption = wb.data.DataFrame('EG.FEC.RNEW.ZS', ['AFG', 'ARG','BRA','CHN','DEU','FRA','GBR','JPN','LBN','POL','UKR','URY','USA'], time=range(2010,2021))
renewable_energy_consumption.head()
renewable_energy_consumption.reset_index().to_sql('renewable_energy_consumption', engine, 'sustainable_var', if_exists='replace', index=False)

# %%
forest_area = wb.data.DataFrame('AG.LND.FRST.K2', ['AFG', 'ARG','BRA','CHN','DEU','FRA','GBR','JPN','LBN','POL','UKR','URY','USA'], time=range(2010,2021))
forest_area.head()
forest_area.reset_index().to_sql('forest_area', engine, 'sustainable_var', if_exists='replace', index=False)
# Out:
# ---------------------------------------------------------------------------
# OperationalError                          Traceback (most recent call last)
# File ~/anaconda3/lib/python3.11/site-packages/sqlalchemy/engine/base.py:1819, in Connection._execute_context(self, dialect, constructor, statement, parameters, execution_options, *args, **kw)
#    1818     if not evt_handled:
# -> 1819         self.dialect.do_execute(
#    1820             cursor, statement, parameters, context
#    1821         )
#    1823 if self._has_events or self.engine._has_events:
#
# File ~/anaconda3/lib/python3.11/site-packages/sqlalchemy/engine/default.py:732, in DefaultDialect.do_execute(self, cursor, statement, parameters, context)
#     731 def do_execute(self, cursor, statement, parameters, context=None):
# --> 732     cursor.execute(statement, parameters)
#
# File ~/anaconda3/lib/python3.11/site-packages/pymysql/cursors.py:153, in Cursor.execute(self, query, args)
#     151 query = self.mogrify(query, args)
# --> 153 result = self._query(query)
#     154 self._executed = query
#
# File ~/anaconda3/lib/python3.11/site-packages/pymysql/cursors.py:322, in Cursor._query(self, q)
#     321 self._clear_result()
# --> 322 conn.query(q)
#     323 self._do_get_result()
#
# File ~/anaconda3/lib/python3.11/site-packages/pymysql/connections.py:558, in Connection.query(self, sql, unbuffered)
#     557 self._execute_command(COMMAND.COM_QUERY, sql)
# --> 558 self._affected_rows = self._read_query_result(unbuffered=unbuffered)
#     559 return self._affected_rows
#
# File ~/anaconda3/lib/python3.11/site-packages/pymysql/connections.py:822, in Connection._read_query_result(self, unbuffered)
#     821     result = MySQLResult(self)
# --> 822     result.read()
#     823 self._result = result
#
# File ~/anaconda3/lib/python3.11/site-packages/pymysql/connections.py:1200, in MySQLResult.read(self)
#    1199 try:
# -> 1200     first_packet = self.connection._read_packet()
#    1202     if first_packet.is_ok_packet():
#
# File ~/anaconda3/lib/python3.11/site-packages/pymysql/connections.py:772, in Connection._read_packet(self, packet_type)
#     771         self._result.unbuffered_active = False
# --> 772     packet.raise_for_error()
#     773 return packet
#
# File ~/anaconda3/lib/python3.11/site-packages/pymysql/protocol.py:221, in MysqlPacket.raise_for_error(self)
#     220     print("errno =", errno)
# --> 221 err.raise_mysql_exception(self._data)
#
# File ~/anaconda3/lib/python3.11/site-packages/pymysql/err.py:143, in raise_mysql_exception(data)
#     142     errorclass = InternalError if errno < 1000 else OperationalError
# --> 143 raise errorclass(errno, errval)
#
# OperationalError: (1049, "Unknown database 'sustainable_var'")
#
# The above exception was the direct cause of the following exception:
#
# OperationalError                          Traceback (most recent call last)
# Cell In[19], line 3
#       1 forest_area = wb.data.DataFrame('AG.LND.FRST.K2', ['AFG', 'ARG','BRA','CHN','DEU','FRA','GBR','JPN','LBN','POL','UKR','URY','USA'], time=range(2010,2021))
#       2 forest_area.head()
# ----> 3 forest_area.reset_index().to_sql('forest_area', engine, 'sustainable_var', if_exists='replace', index=False)
#
# File ~/anaconda3/lib/python3.11/site-packages/pandas/core/generic.py:2878, in NDFrame.to_sql(self, name, con, schema, if_exists, index, index_label, chunksize, dtype, method)
#    2713 """
#    2714 Write records stored in a DataFrame to a SQL database.
#    2715
#    (...)
#    2874 [(1,), (None,), (2,)]
#    2875 """  # noqa:E501
#    2876 from pandas.io import sql
# -> 2878 return sql.to_sql(
#    2879     self,
#    2880     name,
#    2881     con,
#    2882     schema=schema,
#    2883     if_exists=if_exists,
#    2884     index=index,
#    2885     index_label=index_label,
#    2886     chunksize=chunksize,
#    2887     dtype=dtype,
#    2888     method=method,
#    2889 )
#
# File ~/anaconda3/lib/python3.11/site-packages/pandas/io/sql.py:769, in to_sql(frame, name, con, schema, if_exists, index, index_label, chunksize, dtype, method, engine, **engine_kwargs)
#     764     raise NotImplementedError(
#     765         "'frame' argument should be either a Series or a DataFrame"
#     766     )
#     768 with pandasSQL_builder(con, schema=schema, need_transaction=True) as pandas_sql:
# --> 769     return pandas_sql.to_sql(
#     770         frame,
#     771         name,
#     772         if_exists=if_exists,
#     773         index=index,
#     774         index_label=index_label,
#     775         schema=schema,
#     776         chunksize=chunksize,
#     777         dtype=dtype,
#     778         method=method,
#     779         engine=engine,
#     780         **engine_kwargs,
#     781     )
#
# File ~/anaconda3/lib/python3.11/site-packages/pandas/io/sql.py:1910, in SQLDatabase.to_sql(self, frame, name, if_exists, index, index_label, schema, chunksize, dtype, method, engine, **engine_kwargs)
#    1860 """
#    1861 Write records stored in a DataFrame to a SQL database.
#    1862
#    (...)
#    1906     Any additional kwargs are passed to the engine.
#    1907 """
#    1908 sql_engine = get_engine(engine)
# -> 1910 table = self.prep_table(
#    1911     frame=frame,
#    1912     name=name,
#    1913     if_exists=if_exists,
#    1914     index=index,
#    1915     index_label=index_label,
#    1916     schema=schema,
#    1917     dtype=dtype,
#    1918 )
#    1920 total_inserted = sql_engine.insert_records(
#    1921     table=table,
#    1922     con=self.con,
#    (...)
#    1929     **engine_kwargs,
#    1930 )
#    1932 self.check_case_sensitive(name=name, schema=schema)
#
# File ~/anaconda3/lib/python3.11/site-packages/pandas/io/sql.py:1814, in SQLDatabase.prep_table(self, frame, name, if_exists, index, index_label, schema, dtype)
#    1802             raise ValueError(f"The type of {col} is not a SQLAlchemy type")
#    1804 table = SQLTable(
#    1805     name,
#    1806     self,
#    (...)
#    1812     dtype=dtype,
#    1813 )
# -> 1814 table.create()
#    1815 return table
#
# File ~/anaconda3/lib/python3.11/site-packages/pandas/io/sql.py:914, in SQLTable.create(self)
#     912         raise ValueError(f"'{self.if_exists}' is not valid for if_exists")
#     913 else:
# --> 914     self._execute_create()
#
# File ~/anaconda3/lib/python3.11/site-packages/pandas/io/sql.py:900, in SQLTable._execute_create(self)
#     898 self.table = self.table.to_metadata(self.pd_sql.meta)
#     899 with self.pd_sql.run_transaction():
# --> 900     self.table.create(bind=self.pd_sql.con)
#
# File ~/anaconda3/lib/python3.11/site-packages/sqlalchemy/sql/schema.py:959, in Table.create(self, bind, checkfirst)
#     957 if bind is None:
#     958     bind = _bind_or_error(self)
# --> 959 bind._run_ddl_visitor(ddl.SchemaGenerator, self, checkfirst=checkfirst)
#
# File ~/anaconda3/lib/python3.11/site-packages/sqlalchemy/engine/base.py:2130, in Connection._run_ddl_visitor(self, visitorcallable, element, **kwargs)
#    2123 def _run_ddl_visitor(self, visitorcallable, element, **kwargs):
#    2124     """run a DDL visitor.
#    2125
#    2126     This method is only here so that the MockConnection can change the
#    2127     options given to the visitor so that "checkfirst" is skipped.
#    2128
#    2129     """
# -> 2130     visitorcallable(self.dialect, self, **kwargs).traverse_single(element)
#
# File ~/anaconda3/lib/python3.11/site-packages/sqlalchemy/sql/visitors.py:524, in ExternalTraversal.traverse_single(self, obj, **kw)
#     522 meth = getattr(v, "visit_%s" % obj.__visit_name__, None)
#     523 if meth:
# --> 524     return meth(obj, **kw)
#
# File ~/anaconda3/lib/python3.11/site-packages/sqlalchemy/sql/ddl.py:895, in SchemaGenerator.visit_table(self, table, create_ok, include_foreign_key_constraints, _is_metadata_operation)
#     891 if not self.dialect.supports_alter:
#     892     # e.g., don't omit any foreign key constraints
#     893     include_foreign_key_constraints = None
# --> 895 self.connection.execute(
#     896     # fmt: off
#     897     CreateTable(
#     898         table,
#     899         include_foreign_key_constraints=  # noqa
#     900             include_foreign_key_constraints,  # noqa
#     901     )
#     902     # fmt: on
#     903 )
#     905 if hasattr(table, "indexes"):
#     906     for index in table.indexes:
#
# File ~/anaconda3/lib/python3.11/site-packages/sqlalchemy/engine/base.py:1306, in Connection.execute(self, statement, *multiparams, **params)
#    1302     util.raise_(
#    1303         exc.ObjectNotExecutableError(statement), replace_context=err
#    1304     )
#    1305 else:
# -> 1306     return meth(self, multiparams, params, _EMPTY_EXECUTION_OPTS)
#
# File ~/anaconda3/lib/python3.11/site-packages/sqlalchemy/sql/ddl.py:80, in DDLElement._execute_on_connection(self, connection, multiparams, params, execution_options)
#      77 def _execute_on_connection(
#      78     self, connection, multiparams, params, execution_options
#      79 ):
# ---> 80     return connection._execute_ddl(
#      81         self, multiparams, params, execution_options
#      82     )
#
# File ~/anaconda3/lib/python3.11/site-packages/sqlalchemy/engine/base.py:1398, in Connection._execute_ddl(self, ddl, multiparams, params, execution_options)
#    1393 dialect = self.dialect
#    1395 compiled = ddl.compile(
#    1396     dialect=dialect, schema_translate_map=schema_translate_map
#    1397 )
# -> 1398 ret = self._execute_context(
#    1399     dialect,
#    1400     dialect.execution_ctx_cls._init_ddl,
#    1401     compiled,
#    1402     None,
#    1403     execution_options,
#    1404     compiled,
#    1405 )
#    1406 if self._has_events or self.engine._has_events:
#    1407     self.dispatch.after_execute(
#    1408         self,
#    1409         ddl,
#    (...)
#    1413         ret,
#    1414     )
#
# File ~/anaconda3/lib/python3.11/site-packages/sqlalchemy/engine/base.py:1862, in Connection._execute_context(self, dialect, constructor, statement, parameters, execution_options, *args, **kw)
#    1859             branched.close()
#    1861 except BaseException as e:
# -> 1862     self._handle_dbapi_exception(
#    1863         e, statement, parameters, cursor, context
#    1864     )
#    1866 return result
#
# File ~/anaconda3/lib/python3.11/site-packages/sqlalchemy/engine/base.py:2043, in Connection._handle_dbapi_exception(self, e, statement, parameters, cursor, context)
#    2041     util.raise_(newraise, with_traceback=exc_info[2], from_=e)
#    2042 elif should_wrap:
# -> 2043     util.raise_(
#    2044         sqlalchemy_exception, with_traceback=exc_info[2], from_=e
#    2045     )
#    2046 else:
#    2047     util.raise_(exc_info[1], with_traceback=exc_info[2])
#
# File ~/anaconda3/lib/python3.11/site-packages/sqlalchemy/util/compat.py:208, in raise_(***failed resolving arguments***)
#     205     exception.__cause__ = replace_context
#     207 try:
# --> 208     raise exception
#     209 finally:
#     210     # credit to
#     211     # https://cosmicpercolator.com/2016/01/13/exception-leaks-in-python-2-and-3/
#     212     # as the __traceback__ object creates a cycle
#     213     del exception, replace_context, from_, with_traceback
#
# File ~/anaconda3/lib/python3.11/site-packages/sqlalchemy/engine/base.py:1819, in Connection._execute_context(self, dialect, constructor, statement, parameters, execution_options, *args, **kw)
#    1817                 break
#    1818     if not evt_handled:
# -> 1819         self.dialect.do_execute(
#    1820             cursor, statement, parameters, context
#    1821         )
#    1823 if self._has_events or self.engine._has_events:
#    1824     self.dispatch.after_cursor_execute(
#    1825         self,
#    1826         cursor,
#    (...)
#    1830         context.executemany,
#    1831     )
#
# File ~/anaconda3/lib/python3.11/site-packages/sqlalchemy/engine/default.py:732, in DefaultDialect.do_execute(self, cursor, statement, parameters, context)
#     731 def do_execute(self, cursor, statement, parameters, context=None):
# --> 732     cursor.execute(statement, parameters)
#
# File ~/anaconda3/lib/python3.11/site-packages/pymysql/cursors.py:153, in Cursor.execute(self, query, args)
#     149     pass
#     151 query = self.mogrify(query, args)
# --> 153 result = self._query(query)
#     154 self._executed = query
#     155 return result
#
# File ~/anaconda3/lib/python3.11/site-packages/pymysql/cursors.py:322, in Cursor._query(self, q)
#     320 conn = self._get_db()
#     321 self._clear_result()
# --> 322 conn.query(q)
#     323 self._do_get_result()
#     324 return self.rowcount
#
# File ~/anaconda3/lib/python3.11/site-packages/pymysql/connections.py:558, in Connection.query(self, sql, unbuffered)
#     556     sql = sql.encode(self.encoding, "surrogateescape")
#     557 self._execute_command(COMMAND.COM_QUERY, sql)
# --> 558 self._affected_rows = self._read_query_result(unbuffered=unbuffered)
#     559 return self._affected_rows
#
# File ~/anaconda3/lib/python3.11/site-packages/pymysql/connections.py:822, in Connection._read_query_result(self, unbuffered)
#     820 else:
#     821     result = MySQLResult(self)
# --> 822     result.read()
#     823 self._result = result
#     824 if result.server_status is not None:
#
# File ~/anaconda3/lib/python3.11/site-packages/pymysql/connections.py:1200, in MySQLResult.read(self)
#    1198 def read(self):
#    1199     try:
# -> 1200         first_packet = self.connection._read_packet()
#    1202         if first_packet.is_ok_packet():
#    1203             self._read_ok_packet(first_packet)
#
# File ~/anaconda3/lib/python3.11/site-packages/pymysql/connections.py:772, in Connection._read_packet(self, packet_type)
#     770     if self._result is not None and self._result.unbuffered_active is True:
#     771         self._result.unbuffered_active = False
# --> 772     packet.raise_for_error()
#     773 return packet
#
# File ~/anaconda3/lib/python3.11/site-packages/pymysql/protocol.py:221, in MysqlPacket.raise_for_error(self)
#     219 if DEBUG:
#     220     print("errno =", errno)
# --> 221 err.raise_mysql_exception(self._data)
#
# File ~/anaconda3/lib/python3.11/site-packages/pymysql/err.py:143, in raise_mysql_exception(data)
#     141 if errorclass is None:
#     142     errorclass = InternalError if errno < 1000 else OperationalError
# --> 143 raise errorclass(errno, errval)
#
# OperationalError: (pymysql.err.OperationalError) (1049, "Unknown database 'sustainable_var'")
# [SQL:
# CREATE TABLE sustainable_var.forest_area (
# 	economy TEXT,
# 	`YR2010` FLOAT(53),
# 	`YR2011` FLOAT(53),
# 	`YR2012` FLOAT(53),
# 	`YR2013` FLOAT(53),
# 	`YR2014` FLOAT(53),
# 	`YR2015` FLOAT(53),
# 	`YR2016` FLOAT(53),
# 	`YR2017` FLOAT(53),
# 	`YR2018` FLOAT(53),
# 	`YR2019` FLOAT(53),
# 	`YR2020` FLOAT(53)
# )
#
# ]
# (Background on this error at: https://sqlalche.me/e/14/e3q8)
